# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random
threshold = 1e-5
word_counter = Counter(int_words)
total_num = len(int_words)
probs = { word: 1-np.sqrt(threshold/(cnt/total_num)) for word,cnt in word_counter.items()}
train_words = [word for word in int_words if random.random()>probs[word]]# The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = random.randint(1, window_size+1)
    start_idx = idx-R if idx-R>0 else 0
    end_idx = idx+R 
    return list(set(words[start_idx:idx]+words[idx+1:end_idx+1]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,[None])
    labels = tf.placeholder(tf.int32,[None,None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200# Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform(shape=[n_vocab, n_embedding], minval=-1,maxval=1))# create embedding weight matrix here
    embed =tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab,n_embedding], stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss( weights=softmax_w,biases=softmax_b,labels=labels,inputs=embed,
                                      num_sampled=n_sampled,num_classes=n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6422 0.6027 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6573 0.6145 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5084 0.6081 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5896 0.6143 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5136 0.6185 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5768 0.6117 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5451 0.6122 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5237 0.6042 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4536 0.6271 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4331 0.6214 sec/batch
# Nearest to these: tsarina, shunting, sanskrit, despotism, ische, amitabh, skynyrd, romanorum,
# Nearest to time: primarily, by, identity, threatens, valdemar, home, zechariah, promised,
# Nearest to s: ruthless, kompiler, manipulated, gibbons, laughs, gloves, an, allow,
# Nearest to use: jaspers, launchers, utter, ivanovich, skara, rooftop, hasmonaean, glow,
# Nearest to new: prp, fakir, emf, rebroadcast, behalf, directionally, deepwater, homeschool,
# Nearest to used: pocock, carpathians, soak, mehemet, prominently, pipp, liz, daro,
# Nearest to are: supercooled, transistor, limited, kt, column, calendarists, transpositional, mcclory,
# Nearest to b: differentials, reidel, acrylamide, dhole, highlight, stepfather, pittori, bellerophon,
# Nearest to event: hg, palmeri, tribunes, catalogues, churning, irresponsible, launch, tex,
# Nearest to magazine: obstruction, gamespot, israelis, eurocheque, untenable, batasuna, morphophonemic, planning,
# Nearest to except: foremost, eph, trauma, constans, mencius, divisors, officers, funds,
# Nearest to placed: holders, trevelyan, adduce, railroads, figuratively, connacht, via, moller,
# Nearest to frac: rabbinical, kornfeld, arian, us, riot, civilisations, rak, lassen,
# Nearest to recorded: understandings, cougars, scarface, pendleton, firestone, plutocracy, game, amiens,
# Nearest to behind: sutherland, voss, idb, wheatstone, hern, president, baronetcy, rishi,
# Nearest to san: wumpus, mototsune, vomit, gelasian, tractors, grad, placentals, huygens,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4848 0.6176 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3821 0.6142 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3077 0.6142 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2243 0.6093 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1603 0.6045 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1471 0.6055 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0536 0.6117 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0524 0.6462 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9847 0.6108 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9635 0.6208 sec/batch
# Nearest to these: sanskrit, ische, membership, distinguished, ensures, males, despotism, criticism,
# Nearest to time: primarily, by, unfortunate, promised, home, identity, threatens, strategy,
# Nearest to s: manipulated, allow, ruthless, an, gave, consistent, tactical, organizations,
# Nearest to use: utter, launchers, still, pannonian, ivanovich, rooftop, sweep, overcome,
# Nearest to new: fakir, joseph, prp, preservation, behalf, emf, serve, subtle,
# Nearest to used: prominently, carpathians, pocock, mehemet, gamma, liz, equations, remain,
# Nearest to are: limited, column, transistor, supercooled, transpositional, kt, rise, james,
# Nearest to b: differentials, duke, reidel, highlight, ll, powerful, quantity, stepfather,
# Nearest to event: hg, catalogues, methods, union, somebody, tex, autonomous, tribunes,
# Nearest to magazine: obstruction, gamespot, whereas, planning, technologically, members, puzzle, israelis,
# Nearest to except: foremost, funds, live, trauma, eph, officers, northern, constans,
# Nearest to placed: holders, railroads, via, adduce, people, union, trevelyan, figuratively,
# Nearest to frac: us, therefore, arian, rabbinical, k, prohibition, possibilities, dot,
# Nearest to recorded: game, understandings, scarface, grounds, ourselves, hegel, country, pendleton,
# Nearest to behind: sutherland, president, idb, diminution, constituency, rishi, limb, injury,
# Nearest to san: wumpus, grad, vomit, tractors, placentals, mototsune, gelasian, itineraries,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9447 0.6410 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8946 0.6200 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8944 0.6162 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8788 0.6256 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7907 0.6112 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8359 0.6129 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7885 0.6194 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7762 0.6111 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7867 0.6198 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7832 0.6215 sec/batch
# Nearest to these: ische, sanskrit, situational, despotism, criticism, romanorum, shunting, trudeau,
# Nearest to time: unfortunate, primarily, by, transmitters, promised, strategy, threatens, home,
# Nearest to s: ruthless, gibbons, manipulated, laughs, gave, an, tactical, insurrection,
# Nearest to use: utter, launchers, overcome, hardest, glow, ivanovich, sweep, jaspers,
# Nearest to new: fakir, preservation, emf, joseph, prp, behalf, newton, directionally,
# Nearest to used: prominently, pocock, equations, carpathians, gamma, mehemet, soak, skilled,
# Nearest to are: limited, supercooled, column, transistor, transpositional, calendarists, objective, oriente,
# Nearest to b: differentials, duke, reidel, highlight, powerful, ll, acrylamide, heifer,
# Nearest to event: hg, autonomous, catalogues, launch, union, tex, somebody, unlimited,
# Nearest to magazine: obstruction, gamespot, technologically, whereas, untenable, israelis, puzzle, planning,
# Nearest to except: foremost, funds, eph, trauma, live, constans, northern, affecting,
# Nearest to placed: holders, adduce, railroads, trevelyan, figuratively, via, union, millennium,
# Nearest to frac: therefore, k, arian, prohibition, rabbinical, civilisations, guidance, us,
# Nearest to recorded: understandings, grounds, scarface, ourselves, phrases, game, hegel, venous,
# Nearest to behind: sutherland, constituency, idb, president, mounting, injury, limb, rishi,
# Nearest to san: wumpus, grad, vomit, prevail, hottest, tractors, evolve, shipped,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8034 0.6335 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7661 0.6431 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7055 0.6439 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7143 0.6274 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7351 0.6425 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6759 0.6389 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6982 0.6451 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7032 0.6743 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6954 0.5936 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6462 0.5834 sec/batch
# Nearest to these: ische, romanorum, situational, despotism, sanskrit, criticism, preponderance, versuch,
# Nearest to time: indictment, primarily, by, strategy, unfortunate, transmitters, illegality, threatens,
# Nearest to s: ruthless, gibbons, laughs, an, neglect, manipulated, shoreline, leonid,
# Nearest to use: utter, launchers, hardest, glow, counterpoint, appliances, ores, overcome,
# Nearest to new: fakir, joseph, prp, emf, preservation, loewe, directionally, deepwater,
# Nearest to used: pocock, equations, propellants, soak, prominently, carpathians, gamma, telekinesis,
# Nearest to are: limited, supercooled, transistor, column, calendarists, oriente, transpositional, goal,
# Nearest to b: duke, differentials, reidel, swedish, biochemist, essayist, lorraine, acrylamide,
# Nearest to event: hg, autonomous, catalogues, tribunes, launch, union, propellers, somebody,
# Nearest to magazine: untenable, gamespot, obstruction, israelis, technologically, whereas, eschatology, sermon,
# Nearest to except: foremost, trauma, funds, eph, constans, affecting, pataca, divisors,
# Nearest to placed: holders, adduce, trevelyan, railroads, via, figuratively, connacht, union,
# Nearest to frac: k, therefore, rabbinical, cosine, g, civilisations, cdot, guidance,
# Nearest to recorded: scarface, grounds, understandings, phrases, ourselves, firestone, pendleton, venous,
# Nearest to behind: sutherland, voss, constituency, mounting, hern, depp, foote, idb,
# Nearest to san: wumpus, grad, vomit, tractors, hottest, mototsune, everly, nkjv,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6733 0.6432 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6852 0.6586 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5899 0.6406 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6508 0.6793 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6296 0.6503 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6494 0.5891 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6156 0.4441 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5894 0.6031 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4984 0.6085 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5073 0.5896 sec/batch
# Nearest to these: ische, romanorum, situational, preponderance, versuch, despotism, quanta, perpendicular,
# Nearest to time: indictment, primarily, unfortunate, threatens, strategy, trending, transmitters, by,
# Nearest to s: gibbons, ruthless, an, neglect, insurrection, manipulated, shoreline, accredited,
# Nearest to use: utter, launchers, overcome, hardest, appliances, ores, glow, os,
# Nearest to new: fakir, joseph, loewe, emf, deepwater, prp, madge, directionally,
# Nearest to used: pocock, propellants, soak, equations, require, carpathians, gamma, switching,
# Nearest to are: limited, supercooled, transistor, objective, column, phosphorus, oriente, calendarists,
# Nearest to b: duke, swedish, differentials, biochemist, mathematician, journalist, reidel, photographer,
# Nearest to event: hg, autonomous, tribunes, catalogues, launch, propellers, trident, somebody,
# Nearest to magazine: untenable, obstruction, gamespot, eschatology, israelis, technologically, offending, whereas,
# Nearest to except: foremost, trauma, constans, eph, funds, pataca, affecting, lecturing,
# Nearest to placed: holders, trevelyan, adduce, railroads, via, figuratively, connacht, nanometers,
# Nearest to frac: k, cdot, cosine, therefore, g, finite, rabbinical, function,
# Nearest to recorded: grounds, scarface, venous, phrases, amiens, firestone, understandings, country,
# Nearest to behind: sutherland, voss, constituency, depp, hern, rishi, mounting, foote,
# Nearest to san: wumpus, vomit, grad, tractors, mototsune, hottest, gelasian, everly,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5054 0.6010 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4950 0.5834 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4603 0.5831 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5574 0.5918 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4910 0.6240 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4918 0.6173 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4555 0.6030 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4263 0.6062 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4248 0.6104 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4338 0.6011 sec/batch
# Nearest to these: ische, romanorum, situational, preponderance, versuch, despotism, perpendicular, substances,
# Nearest to time: indictment, strategy, primarily, trending, transmitters, threatens, looting, unfortunate,
# Nearest to s: gibbons, ruthless, an, neglect, higham, laughs, dreams, airplay,
# Nearest to use: utter, launchers, overcome, hardest, appliances, hasmonaean, glow, counterpoint,
# Nearest to new: fakir, loewe, joseph, deepwater, emf, prp, directionally, anglicans,
# Nearest to used: pocock, propellants, soak, fluids, require, equations, advertising, gamma,
# Nearest to are: limited, supercooled, phosphorus, column, certain, calendarists, behaviors, transistor,
# Nearest to b: differentials, duke, swedish, reidel, biochemist, essayist, mathematician, acrylamide,
# Nearest to event: hg, tribunes, week, propellers, trident, autonomous, launch, catalogues,
# Nearest to magazine: eschatology, untenable, obstruction, hauptmann, offending, gamespot, israelis, sermon,
# Nearest to except: foremost, trauma, pataca, constans, funds, seamlessly, eph, could,
# Nearest to placed: adduce, holders, railroads, via, trevelyan, figuratively, connacht, metals,
# Nearest to frac: k, cdot, cosine, finite, function, riemann, g, therefore,
# Nearest to recorded: scarface, venous, phrases, grounds, understandings, firestone, pendleton, country,
# Nearest to behind: sutherland, voss, constituency, hern, depp, mounting, wheatstone, baronetcy,
# Nearest to san: wumpus, vomit, mototsune, tractors, grad, everly, gelasian, karabakh,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4350 0.6161 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4289 0.6017 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4181 0.6012 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3993 0.5921 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4219 0.5782 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4339 0.5741 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3789 0.6337 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3719 0.6438 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3905 0.6457 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3975 0.6544 sec/batch
# Nearest to these: ische, romanorum, preponderance, situational, despotism, versuch, perpendicular, quanta,
# Nearest to time: indictment, strategy, trending, transmitters, primarily, looting, illegality, unfortunate,
# Nearest to s: gibbons, ruthless, an, neglect, manipulated, dreams, laughs, higham,
# Nearest to use: utter, launchers, appliances, overcome, lubricated, hardest, counterpoint, implicit,
# Nearest to new: fakir, loewe, joseph, emf, deepwater, nascar, directionally, serve,
# Nearest to used: pocock, propellants, soak, fluids, require, symbols, genera, gamma,
# Nearest to are: limited, supercooled, phosphorus, column, transistor, patagonian, transpositional, gamut,
# Nearest to b: differentials, duke, swedish, essayist, mathematician, reidel, biochemist, lorraine,
# Nearest to event: hg, tribunes, trident, propellers, week, sycamore, palmeri, versioning,
# Nearest to magazine: eschatology, untenable, offending, hauptmann, obstruction, stanford, technologically, singer,
# Nearest to except: trauma, foremost, pataca, constans, funds, eph, seamlessly, could,
# Nearest to placed: adduce, holders, via, trevelyan, figuratively, railroads, metals, connacht,
# Nearest to frac: cdot, k, cosine, function, riemann, g, finite, alpha,
# Nearest to recorded: scarface, venous, phrases, song, understandings, grounds, firestone, pendleton,
# Nearest to behind: sutherland, voss, constituency, depp, injury, mounting, baronetcy, wheatstone,
# Nearest to san: wumpus, mototsune, vomit, grad, everly, tractors, gelasian, karabakh,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3844 0.6854 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3726 0.7291 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3668 0.6879 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3756 0.7463 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3987 0.7014 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.4042 0.7303 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3749 0.7213 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3817 0.7181 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3140 0.6772 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3588 0.6275 sec/batch
# Nearest to these: romanorum, ische, situational, despotism, preponderance, mellitus, quanta, versuch,
# Nearest to time: strategy, indictment, trending, transmitters, looting, defying, threatens, unfortunate,
# Nearest to s: gibbons, ruthless, an, manipulated, expletive, neglect, higham, airplay,
# Nearest to use: utter, appliances, launchers, overcome, hardest, lubricated, hasmonaean, counterpoint,
# Nearest to new: fakir, loewe, emf, dpr, joseph, anglicans, deepwater, newton,
# Nearest to used: pocock, propellants, soak, fluids, symbols, advertising, genera, interfaces,
# Nearest to are: limited, supercooled, acoustics, phosphorus, represented, certain, patagonian, behaviors,
# Nearest to b: differentials, duke, biochemist, reidel, mathematician, essayist, swedish, acrylamide,
# Nearest to event: hg, tribunes, trident, week, adidas, wormhole, propellers, sycamore,
# Nearest to magazine: stanford, offending, untenable, hauptmann, gamespot, batasuna, singer, technologically,
# Nearest to except: trauma, foremost, pataca, constans, seamlessly, acetaldehyde, funds, bosses,
# Nearest to placed: adduce, holders, figuratively, railroads, via, trevelyan, woodford, metals,
# Nearest to frac: cdot, cosine, riemann, k, g, function, injective, dot,
# Nearest to recorded: scarface, phrases, song, venous, grounds, khalq, cried, pendleton,
# Nearest to behind: sutherland, voss, constituency, depp, injury, wheatstone, hern, mounting,
# Nearest to san: wumpus, mototsune, vomit, everly, gelasian, tractors, grad, karabakh,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3524 0.6525 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2946 0.6505 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3734 0.6409 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.4036 0.6524 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3813 0.6331 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2819 0.6524 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3068 0.6369 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3386 0.6346 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2513 0.6429 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2994 0.6408 sec/batch
# Nearest to these: ische, preponderance, romanorum, situational, despotism, quanta, mellitus, quantified,
# Nearest to time: indictment, strategy, looting, defying, feigning, transmitters, unfortunate, threatens,
# Nearest to s: gibbons, ruthless, an, neglect, expletive, manipulated, higham, airplay,
# Nearest to use: utter, appliances, launchers, lubricated, counterpoint, overcome, hardest, implicit,
# Nearest to new: fakir, loewe, emf, dpr, nascar, joseph, karlsruhe, homeschool,
# Nearest to used: pocock, propellants, soak, fluids, symbols, genera, interfaces, prominently,
# Nearest to are: supercooled, limited, acoustics, communities, represented, patagonian, certain, condense,
# Nearest to b: duke, differentials, biochemist, mathematician, essayist, swedish, reidel, sculptor,
# Nearest to event: hg, trident, week, adidas, tribunes, intellivision, wormhole, adoptionism,
# Nearest to magazine: offending, gamespot, untenable, hutchence, addison, hauptmann, agains, stanford,
# Nearest to except: trauma, foremost, constans, pataca, seamlessly, region, testers, acetaldehyde,
# Nearest to placed: adduce, holders, metals, figuratively, via, fuses, railroads, trevelyan,
# Nearest to frac: cdot, cosine, riemann, g, k, injective, dot, v,
# Nearest to recorded: scarface, phrases, song, country, pendleton, firestone, khalq, cca,
# Nearest to behind: sutherland, voss, constituency, injury, depp, mounting, foote, wheatstone,
# Nearest to san: wumpus, mototsune, vomit, tractors, everly, grad, karabakh, gelasian,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3042 0.6597 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2861 0.6476 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3302 0.3038 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2467 0.6485 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2554 0.6332 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2378 0.6481 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2343 0.6429 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2025 0.6380 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2138 0.6440 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1830 0.6381 sec/batch
# Nearest to these: preponderance, romanorum, despotism, ische, thirds, quanta, mellitus, situational,
# Nearest to time: strategy, indictment, transmitters, looting, feigning, defying, threatens, illegality,
# Nearest to s: gibbons, ruthless, an, neglect, expletive, airplay, manipulated, organizes,
# Nearest to use: utter, launchers, appliances, counterpoint, lubricated, overcome, hasmonaean, adjust,
# Nearest to new: fakir, dpr, emf, homeschool, nascar, loewe, computing, statuary,
# Nearest to used: pocock, soak, propellants, genera, isostatic, symbols, fluids, flexible,
# Nearest to are: supercooled, communities, limited, acoustics, cultivation, patagonian, condense, certain,
# Nearest to b: biochemist, duke, differentials, mathematician, essayist, reidel, swedish, sculptor,
# Nearest to event: hg, week, trident, sycamore, adoptionism, adidas, screwball, tribunes,
# Nearest to magazine: listings, hutchence, gamespot, offending, untenable, obstruction, surpassing, hauptmann,
# Nearest to except: foremost, trauma, pataca, seamlessly, constans, region, lingerie, mentats,
# Nearest to placed: adduce, holders, figuratively, woodford, railroads, fuses, trevelyan, sociable,
# Nearest to frac: cdot, riemann, cosine, k, g, injective, dot, omega,
# Nearest to recorded: phrases, scarface, country, song, oeuvre, cca, grounds, firestone,
# Nearest to behind: voss, sutherland, constituency, injury, depp, wheatstone, mounting, dissonant,
# Nearest to san: mototsune, wumpus, vomit, edgy, aussie, everly, karabakh, tractors,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2578 0.6449 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2192 0.6425 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2370 0.6304 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1469 0.6496 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1669 0.6462 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1916 0.6227 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1575 0.6389 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1810 0.6389 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2016 0.6331 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1849 0.6423 sec/batch
# Nearest to these: despotism, preponderance, romanorum, quanta, ische, weismann, quantified, thirds,
# Nearest to time: strategy, indictment, transmitters, defying, looting, feigning, threatens, illegality,
# Nearest to s: gibbons, an, expletive, ruthless, neglect, higham, manipulated, airplay,
# Nearest to use: utter, appliances, lubricated, launchers, counterpoint, overcome, implicit, udi,
# Nearest to new: dpr, fakir, emf, loewe, homeschool, karlsruhe, underhill, nascar,
# Nearest to used: pocock, propellants, soak, fluids, interfaces, flexible, symbols, genera,
# Nearest to are: supercooled, condense, acoustics, manifolds, communities, certain, affixes, represented,
# Nearest to b: differentials, duke, biochemist, mathematician, reidel, quad, essayist, acrylamide,
# Nearest to event: hg, week, sycamore, screwball, trident, adoptionism, dac, grounds,
# Nearest to magazine: offending, gamespot, listings, hutchence, obstruction, untenable, marge, gregers,
# Nearest to except: trauma, foremost, pataca, seamlessly, acetaldehyde, constans, lingerie, mentats,
# Nearest to placed: adduce, holders, figuratively, metals, horizon, woodford, fuses, railroads,
# Nearest to frac: cdot, riemann, cosine, k, omega, g, f, injective,
# Nearest to recorded: phrases, song, scarface, oeuvre, country, firestone, rock, cca,
# Nearest to behind: voss, sutherland, constituency, injury, wheatstone, depp, cowboys, mounting,
# Nearest to san: mototsune, wumpus, vomit, aussie, everly, edgy, tractors, karabakh,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.2001 0.6345 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2222 0.6441 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1874 0.6490 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1394 0.6371 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1826 0.6843 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1687 0.6723 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1854 0.6286 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1656 0.6383 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1672 0.6388 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2102 0.6330 sec/batch
# Nearest to these: romanorum, despotism, preponderance, quanta, weismann, ische, mellitus, thirds,
# Nearest to time: transmitters, strategy, indictment, feigning, looting, illegality, defying, integrase,
# Nearest to s: gibbons, an, expletive, neglect, ruthless, higham, organizes, manipulated,
# Nearest to use: lubricated, utter, appliances, counterpoint, implicit, launchers, bikes, udi,
# Nearest to new: dpr, emf, newton, fakir, computing, anglicans, loewe, homeschool,
# Nearest to used: pocock, propellants, soak, symbols, fluids, klaviertrio, interfaces, hatchet,
# Nearest to are: supercooled, electronvolt, cath, represented, certain, garments, acoustics, condense,
# Nearest to b: differentials, duke, biochemist, reidel, mathematician, quad, essayist, swedish,
# Nearest to event: hg, week, sycamore, screwball, trident, adoptionism, period, adidas,
# Nearest to magazine: offending, hutchence, listings, gamespot, marge, gregers, untenable, addison,
# Nearest to except: trauma, foremost, pataca, acetaldehyde, constans, seamlessly, mentats, lingerie,
# Nearest to placed: adduce, holders, woodford, figuratively, fuses, horizon, metals, thigh,
# Nearest to frac: cdot, riemann, cosine, k, omega, g, therefore, injective,
# Nearest to recorded: song, phrases, country, oeuvre, scarface, cougars, rock, composited,
# Nearest to behind: voss, sutherland, mounting, constituency, wheatstone, injury, depp, chelsea,
# Nearest to san: mototsune, wumpus, vomit, everly, aussie, gelasian, expressive, edgy,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2166 0.6544 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1703 0.6341 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1869 0.6388 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2044 0.6325 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1870 0.6333 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1814 0.6420 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1938 0.6293 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1636 0.6347 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2038 0.6442 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2127 0.6266 sec/batch
# Nearest to these: despotism, romanorum, preponderance, weismann, ische, enzyte, trier, situational,
# Nearest to time: looting, feigning, strategy, indictment, transmitters, threatens, by, defying,
# Nearest to s: an, gibbons, ruthless, expletive, higham, neglect, organizes, consistent,
# Nearest to use: utter, lubricated, appliances, counterpoint, implicit, bikes, launchers, millisecond,
# Nearest to new: dpr, emf, fakir, homeschool, anglicans, newton, joseph, loewe,
# Nearest to used: pocock, soak, klaviertrio, propellants, interfaces, syntax, symbols, fluids,
# Nearest to are: supercooled, represented, cath, electronvolt, certain, families, communities, limited,
# Nearest to b: duke, biochemist, reidel, differentials, essayist, mathematician, photographer, swedish,
# Nearest to event: hg, week, screwball, sycamore, trident, adoptionism, adidas, union,
# Nearest to magazine: listings, gregers, hutchence, offending, gamespot, marge, addison, email,
# Nearest to except: pataca, acetaldehyde, trauma, foremost, lingerie, constans, mencius, mentats,
# Nearest to placed: adduce, holders, figuratively, woodford, thigh, fuses, horizon, tu,
# Nearest to frac: cdot, riemann, cosine, omega, k, g, injective, therefore,
# Nearest to recorded: song, phrases, country, oeuvre, rock, scarface, cca, cougars,
# Nearest to behind: voss, mounting, sutherland, injury, constituency, depp, wheatstone, consanguinity,
# Nearest to san: mototsune, wumpus, vomit, expressive, aussie, everly, edgy, gelasian,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2331 0.6547 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1612 0.6480 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1325 0.6455 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1851 0.6492 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0387 0.6279 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1391 0.6472 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1496 0.6400 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1418 0.6329 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1796 0.1425 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1017 0.6220 sec/batch
# Nearest to these: quanta, despotism, preponderance, romanorum, farmland, thirds, weismann, situational,
# Nearest to time: feigning, looting, transmitters, strategy, defying, rhetorica, indictment, by,
# Nearest to s: an, gibbons, ruthless, expletive, neglect, consistent, higham, organizes,
# Nearest to use: utter, bikes, lubricated, appliances, launchers, counterpoint, firefighting, millisecond,
# Nearest to new: dpr, emf, homeschool, fakir, loewe, newton, tyrolean, rebroadcast,
# Nearest to used: pocock, propellants, soak, fluids, klaviertrio, thais, motherboard, hermite,
# Nearest to are: families, supercooled, snails, garments, cultivation, electronvolt, acoustics, hotspot,
# Nearest to b: differentials, biochemist, duke, reidel, quad, essayist, mathematician, pittori,
# Nearest to event: hg, week, screwball, union, trident, sycamore, adidas, adoptionism,
# Nearest to magazine: listings, gregers, hutchence, gamespot, marge, offending, communicator, email,
# Nearest to except: pataca, acetaldehyde, foremost, trauma, orthography, mentats, seamlessly, constans,
# Nearest to placed: adduce, figuratively, holders, fuses, woodford, horizon, vertical, thigh,
# Nearest to frac: cdot, riemann, cosine, omega, dot, therefore, g, injective,
# Nearest to recorded: song, country, phrases, rock, oeuvre, cca, scarface, aconcagua,
# Nearest to behind: voss, injury, sutherland, constituency, mounting, depp, cowboys, wheatstone,
# Nearest to san: mototsune, wumpus, vomit, expressive, mutharika, karabakh, gelasian, everly,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0792 0.6717 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0754 0.6473 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1195 0.6323 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0970 0.6394 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0834 0.6310 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0349 0.6316 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0925 0.6396 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1230 0.6232 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1506 0.6469 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0255 0.6361 sec/batch
# Nearest to these: despotism, quanta, romanorum, weismann, preponderance, enzyte, senders, ische,
# Nearest to time: transmitters, strategy, looting, feigning, defying, indictment, rebounded, trajectory,
# Nearest to s: an, gibbons, expletive, higham, consistent, neglect, ruthless, lendl,
# Nearest to use: utter, lubricated, appliances, counterpoint, firefighting, hung, launchers, millisecond,
# Nearest to new: dpr, emf, homeschool, nascar, fakir, anglicans, joseph, deepwater,
# Nearest to used: pocock, propellants, soak, fluids, klaviertrio, cleaning, motherboard, thais,
# Nearest to are: snails, families, preschool, garments, cultivation, supercooled, acoustics, condense,
# Nearest to b: differentials, biochemist, quad, reidel, duke, acrylamide, function, nsted,
# Nearest to event: hg, week, union, screwball, trident, period, adidas, adoptionism,
# Nearest to magazine: listings, gamespot, hutchence, gregers, marge, offending, communicator, surpassing,
# Nearest to except: acetaldehyde, pataca, foremost, seamlessly, constans, infielder, trauma, orthography,
# Nearest to placed: holders, adduce, figuratively, fuses, woodford, thigh, vertical, halfway,
# Nearest to frac: cdot, omega, riemann, cosine, therefore, k, velocity, injective,
# Nearest to recorded: song, country, phrases, oeuvre, rock, cca, stokely, aconcagua,
# Nearest to behind: voss, constituency, mounting, wheatstone, injury, depp, sutherland, chelsea,
# Nearest to san: mototsune, vomit, francisco, wumpus, mutharika, expressive, karabakh, aussie,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0432 0.6383 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0250 0.6340 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0141 0.6252 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0524 0.6319 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0862 0.6401 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0718 0.6221 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0893 0.6405 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1375 0.6461 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0456 0.6274 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0618 0.6483 sec/batch
# Nearest to these: quanta, weismann, romanorum, despotism, preponderance, enzyte, distinguished, quantified,
# Nearest to time: transmitters, looting, strategy, feigning, defying, indictment, lookahead, the,
# Nearest to s: an, gibbons, expletive, consistent, higham, lendl, manipulated, builder,
# Nearest to use: utter, counterpoint, appliances, lubricated, millisecond, implicit, overcome, udi,
# Nearest to new: dpr, emf, nascar, homeschool, fakir, newton, west, infoplease,
# Nearest to used: pocock, soak, propellants, fluids, oe, klaviertrio, syntax, usage,
# Nearest to are: families, certain, snails, preschool, gamut, from, communities, allele,
# Nearest to b: differentials, biochemist, reidel, quad, duke, acrylamide, jauron, pittori,
# Nearest to event: hg, week, period, screwball, union, trident, dac, sycamore,
# Nearest to magazine: gamespot, gregers, listings, offending, hutchence, email, communicator, marge,
# Nearest to except: acetaldehyde, pataca, foremost, seamlessly, safeguarding, trauma, constans, orthography,
# Nearest to placed: figuratively, adduce, holders, vertical, thigh, woodford, horizon, fuses,
# Nearest to frac: cdot, omega, riemann, therefore, dot, cosine, constant, k,
# Nearest to recorded: song, phrases, country, oeuvre, rock, stokely, cca, composited,
# Nearest to behind: voss, cowboys, constituency, wheatstone, mounting, chelsea, injury, sutherland,
# Nearest to san: mototsune, vomit, francisco, expressive, wumpus, mutharika, aussie, karabakh,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0972 0.6534 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0822 0.6387 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1173 0.6435 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0793 0.6156 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0747 0.6455 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0700 0.6361 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.1005 0.6253 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0784 0.6473 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1171 0.6332 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0909 0.6383 sec/batch
# Nearest to these: despotism, quanta, romanorum, weismann, preponderance, enzyte, distinguished, trier,
# Nearest to time: transmitters, looting, the, by, feigning, rhetorica, precedence, defying,
# Nearest to s: an, gibbons, expletive, higham, lendl, consistent, sex, builder,
# Nearest to use: utter, counterpoint, lubricated, bikes, implicit, udi, hung, millisecond,
# Nearest to new: dpr, emf, anglicans, homeschool, newton, tyrolean, nascar, ecw,
# Nearest to used: pocock, soak, propellants, fluids, usage, klaviertrio, cleaning, thais,
# Nearest to are: gamut, garments, cath, preschool, allele, funerary, supercooled, acoustics,
# Nearest to b: differentials, biochemist, reidel, quad, duke, jauron, forall, pittori,
# Nearest to event: hg, union, week, screwball, period, trident, unskilled, adidas,
# Nearest to magazine: gregers, gamespot, listings, hutchence, email, offending, communicator, marge,
# Nearest to except: acetaldehyde, pataca, foremost, safeguarding, trauma, orthography, ke, schwa,
# Nearest to placed: holders, adduce, figuratively, woodford, thigh, union, vertical, fuses,
# Nearest to frac: cdot, omega, therefore, riemann, constant, dot, cosine, k,
# Nearest to recorded: song, country, phrases, oeuvre, rock, stokely, posing, cca,
# Nearest to behind: voss, constituency, wheatstone, cowboys, chelsea, consanguinity, depp, sutherland,
# Nearest to san: mototsune, vomit, francisco, expressive, wumpus, mutharika, edgy, aussie,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0840 0.6470 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0219 0.6287 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0261 0.6336 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0865 0.6421 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.1080 0.6425 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1213 0.6461 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1468 0.6160 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0435 0.6478 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0497 0.6361 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0701 0.6277 sec/batch
# Nearest to these: quanta, despotism, enzyte, romanorum, weismann, preponderance, distinguished, senders,
# Nearest to time: looting, feigning, transmitters, by, rhetorica, strategy, the, indictment,
# Nearest to s: an, gibbons, consistent, sex, lendl, expletive, higham, ruthless,
# Nearest to use: utter, lubricated, hung, millisecond, bikes, implicit, appliances, counterpoint,
# Nearest to new: dpr, emf, homeschool, ecw, tyrolean, leibniz, anglicans, nascar,
# Nearest to used: pocock, propellants, usage, fluids, cleaning, klaviertrio, soak, oe,
# Nearest to are: families, snails, represented, limited, gamut, cath, number, hotspot,
# Nearest to b: biochemist, differentials, reidel, quad, jauron, athlete, essayist, pittori,
# Nearest to event: hg, union, week, period, screwball, trident, unskilled, adidas,
# Nearest to magazine: gregers, gamespot, listings, communicator, vets, email, hutchence, offending,
# Nearest to except: acetaldehyde, pataca, orthography, schwa, safeguarding, foremost, smallest, ke,
# Nearest to placed: holders, adduce, union, thigh, figuratively, fuses, vertical, woodford,
# Nearest to frac: cdot, omega, riemann, cosine, dot, therefore, constant, g,
# Nearest to recorded: song, country, rock, phrases, oeuvre, stokely, cca, posing,
# Nearest to behind: voss, constituency, cowboys, sutherland, wheatstone, injury, chelsea, depp,
# Nearest to san: mototsune, francisco, vomit, expressive, mutharika, edgy, wumpus, karabakh,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9709 0.6576 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0294 0.6293 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0307 0.6480 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0272 0.6440 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0995 0.6243 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0483 0.6130 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0277 0.6304 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9710 0.6272 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0235 0.6383 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9929 0.6472 sec/batch
# Nearest to these: despotism, quanta, weismann, enzyte, romanorum, farmland, preponderance, senders,
# Nearest to time: transmitters, looting, feigning, rhetorica, by, strategy, lookahead, paypal,
# Nearest to s: an, consistent, higham, gibbons, expletive, organizes, lendl, total,
# Nearest to use: utter, millisecond, lubricated, bikes, firefighting, implicit, hung, appliances,
# Nearest to new: emf, homeschool, dpr, leibniz, baltimore, tyrolean, anglicans, nascar,
# Nearest to used: pocock, propellants, usage, cleaning, klaviertrio, fluids, soak, oe,
# Nearest to are: snails, families, gamut, calamine, flattened, acoustics, atypical, garments,
# Nearest to b: biochemist, differentials, reidel, essayist, athlete, etienne, duke, quad,
# Nearest to event: hg, union, week, screwball, period, trident, loss, disaster,
# Nearest to magazine: gregers, gamespot, listings, communicator, vets, hutchence, email, hbk,
# Nearest to except: acetaldehyde, pataca, foremost, trauma, safeguarding, seamlessly, twice, schwa,
# Nearest to placed: holders, figuratively, adduce, thigh, vertical, union, fuses, woodford,
# Nearest to frac: cdot, omega, riemann, cosine, dot, constant, therefore, velocity,
# Nearest to recorded: country, song, rock, phrases, stokely, oeuvre, cca, aconcagua,
# Nearest to behind: voss, constituency, decomposition, wheatstone, cowboys, chelsea, sutherland, injury,
# Nearest to san: francisco, mototsune, vomit, expressive, mutharika, edgy, aussie, wumpus,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0089 0.6452 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9657 0.6397 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0254 0.6367 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0330 0.6444 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0511 0.6329 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0254 0.6350 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9493 0.6514 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9628 0.6317 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9606 0.6353 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0105 0.6305 sec/batch
# Nearest to these: enzyte, quanta, despotism, weismann, romanorum, preponderance, distinguished, tdma,
# Nearest to time: looting, transmitters, feigning, strategy, rebounded, rhetorica, integrase, by,
# Nearest to s: an, higham, lendl, consistent, expletive, gibbons, total, builder,
# Nearest to use: millisecond, utter, counterpoint, lubricated, such, implicit, hung, bikes,
# Nearest to new: dpr, emf, homeschool, tyrolean, west, anglicans, baltimore, skyscraper,
# Nearest to used: pocock, propellants, klaviertrio, soak, fluids, oe, usage, cleaning,
# Nearest to are: snails, flattened, families, gamut, certain, calamine, number, from,
# Nearest to b: differentials, biochemist, reidel, quad, forall, function, nsted, jauron,
# Nearest to event: hg, union, week, period, screwball, trident, unskilled, loss,
# Nearest to magazine: gregers, communicator, gamespot, listings, email, hutchence, vets, publication,
# Nearest to except: acetaldehyde, pataca, foremost, safeguarding, twice, smallest, seamlessly, funds,
# Nearest to placed: holders, figuratively, union, thigh, vertical, halfway, adduce, fuses,
# Nearest to frac: cdot, omega, cosine, riemann, therefore, dot, constant, strokes,
# Nearest to recorded: song, rock, country, phrases, oeuvre, cca, stokely, albums,
# Nearest to behind: voss, constituency, cowboys, chelsea, wheatstone, sutherland, injury, mounting,
# Nearest to san: francisco, mototsune, vomit, expressive, mutharika, aussie, edgy, wumpus,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0224 0.6441 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9890 0.6528 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 4.0095 0.6249 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0179 0.6434 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0475 0.6305 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9543 0.6362 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0268 0.6487 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0269 0.6242 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0023 0.6342 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0094 0.6410 sec/batch
# Nearest to these: enzyte, despotism, quanta, romanorum, weismann, preponderance, distinct, distinguished,
# Nearest to time: transmitters, looting, feigning, to, integrase, by, the, immunodeficiency,
# Nearest to s: an, consistent, higham, gibbons, lendl, expletive, builder, pithy,
# Nearest to use: counterpoint, lubricated, such, millisecond, implicit, bikes, hung, utter,
# Nearest to new: dpr, emf, homeschool, baltimore, anglicans, leibniz, tyrolean, ny,
# Nearest to used: pocock, klaviertrio, propellants, usage, fluids, cleaning, thais, abbreviation,
# Nearest to are: cath, certain, flattened, number, polyandry, borda, families, snails,
# Nearest to b: differentials, biochemist, reidel, jauron, athlete, mathematician, essayist, etienne,
# Nearest to event: hg, union, week, period, screwball, gravitational, disaster, trident,
# Nearest to magazine: gregers, communicator, gamespot, listings, email, weldon, hbk, hutchence,
# Nearest to except: acetaldehyde, pataca, twice, safeguarding, tunisia, foremost, smallest, schwa,
# Nearest to placed: holders, figuratively, thigh, adduce, halfway, woodford, doggy, union,
# Nearest to frac: cdot, omega, therefore, riemann, cosine, constant, dot, tarantula,
# Nearest to recorded: song, rock, oeuvre, country, albums, stokely, phrases, cca,
# Nearest to behind: voss, cowboys, constituency, chelsea, sutherland, wheatstone, mounting, consanguinity,
# Nearest to san: francisco, vomit, mototsune, expressive, aussie, mutharika, edgy, wumpus,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0090 0.6438 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0003 0.6388 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0078 0.6243 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0226 0.6397 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0300 0.6499 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0443 0.6361 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0051 0.6400 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9761 0.6369 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9666 0.6323 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0371 0.6486 sec/batch
# Nearest to these: despotism, enzyte, romanorum, weismann, quanta, ische, distinct, hebrides,
# Nearest to time: looting, feigning, transmitters, rhetorica, by, immunodeficiency, the, odes,
# Nearest to s: an, consistent, lendl, gibbons, total, higham, zero, sex,
# Nearest to use: such, millisecond, hung, lubricated, kilns, implicit, bikes, manufactured,
# Nearest to new: emf, dpr, leibniz, homeschool, anglicans, tyrolean, newton, ny,
# Nearest to used: pocock, usage, klaviertrio, cleaning, propellants, fluids, artistes, psychoacoustic,
# Nearest to are: certain, from, flattened, calamine, number, families, electronvolt, allele,
# Nearest to b: differentials, biochemist, reidel, athlete, essayist, jauron, forall, mathematician,
# Nearest to event: hg, union, week, period, screwball, trident, disaster, dac,
# Nearest to magazine: gregers, communicator, gamespot, listings, email, weldon, hbk, vets,
# Nearest to except: acetaldehyde, pataca, smallest, gir, tunisia, safeguarding, twice, schwa,
# Nearest to placed: holders, union, thigh, figuratively, woodford, adduce, halfway, vertical,
# ...
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8631 0.6391 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8545 0.6235 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8684 0.6347 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9456 0.6416 sec/batch
# Nearest to these: enzyte, are, other, many, weismann, despotism, distinct, than,
# Nearest to time: in, the, was, to, gmt, by, immunodeficiency, for,
# Nearest to s: an, as, the, zero, of, with, and, two,
# Nearest to use: such, used, also, chainmail, millisecond, as, other, weapons,
# Nearest to new: york, ny, emergence, in, leibniz, tulip, delaware, becomes,
# Nearest to used: usage, pocock, use, abbreviation, for, also, common, united,
# Nearest to are: have, many, other, usually, their, may, of, families,
# Nearest to b: jauron, biochemist, quad, acrylamide, differentials, medvedev, reidel, travelin,
# Nearest to event: union, screwball, hg, disaster, extinction, unskilled, dac, commemorate,
# Nearest to magazine: gregers, vets, gamespot, publication, wmd, platoons, commuted, magazines,
# Nearest to except: twice, tunisia, safeguarding, acetaldehyde, occupies, fragmenting, gir, viciously,
# Nearest to placed: adduce, doggy, figuratively, strings, vertical, holders, siding, block,
# Nearest to frac: reactance, omega, strokes, cdot, constant, bounced, tarantula, right,
# Nearest to recorded: insulinotherapy, recall, stokely, posing, tour, album, band, oeuvre,
# Nearest to behind: voss, chelsea, dkk, decomposition, sutherland, perceiving, constituency, photovoltaic,
# Nearest to san: francisco, california, expressive, vomit, mototsune, jose, sandpaper, aussie,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8528 0.6456 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8678 0.6304 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8732 0.6203 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.9027 0.6376 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8752 0.6360 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8920 0.6205 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8789 0.6304 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8547 0.6339 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.9097 0.6362 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8849 0.6439 sec/batch
# Nearest to these: are, many, distinct, than, other, despotism, miniature, enzyte,
# Nearest to time: the, in, was, by, of, to, gmt, immunodeficiency,
# Nearest to s: an, of, as, the, and, zero, with, two,
# Nearest to use: such, used, also, chainmail, means, weapons, cutlery, other,
# Nearest to new: york, emergence, ny, leibniz, relentlessly, dpr, tulip, becomes,
# Nearest to used: usage, pocock, use, abbreviation, for, common, menthol, ser,
# Nearest to are: have, many, other, usually, and, may, their, these,
# Nearest to b: jauron, quad, acrylamide, biochemist, differentials, casteljau, octets, reidel,
# Nearest to event: union, screwball, commemorate, hg, extinction, disaster, events, unskilled,
# Nearest to magazine: gregers, magazines, gamespot, publication, vets, wmd, spivak, platoons,
# Nearest to except: twice, tunisia, safeguarding, closer, fragmenting, but, occupies, gir,
# Nearest to placed: adduce, holders, siding, strings, doggy, figuratively, facing, vertical,
# Nearest to frac: reactance, omega, constant, strokes, cdot, bounced, tarantula, right,
# Nearest to recorded: insulinotherapy, tour, album, stokely, recall, posing, november, composited,
# Nearest to behind: voss, decomposition, dkk, chelsea, sutherland, perceiving, omputer, on,
# Nearest to san: francisco, california, vomit, expressive, mototsune, sandpaper, earthquakes, jose,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8921 0.6326 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8426 0.6388 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8662 0.6223 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8710 0.6311 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9171 0.6443 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8381 0.6240 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9892 0.6389 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8969 0.6272 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9066 0.6340 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8217 0.6433 sec/batch
# Nearest to these: are, despotism, many, enzyte, other, distinct, than, larnaca,
# Nearest to time: the, was, in, looting, gmt, by, to, of,
# Nearest to s: an, the, of, as, and, with, a, zero,
# Nearest to use: such, used, chainmail, also, for, weapons, cutlery, oup,
# Nearest to new: york, ny, leibniz, relentlessly, becomes, emergence, tyrolean, walla,
# Nearest to used: usage, pocock, abbreviation, use, for, common, refer, menthol,
# Nearest to are: have, other, many, usually, and, may, these, certain,
# Nearest to b: jauron, quad, differentials, biochemist, acrylamide, medvedev, eleonore, octets,
# Nearest to event: union, screwball, disaster, extinction, commemorate, unskilled, hg, events,
# Nearest to magazine: gregers, magazines, vets, publication, gamespot, wmd, platoons, commuted,
# Nearest to except: tunisia, twice, safeguarding, viciously, gir, fragmenting, closer, acetaldehyde,
# Nearest to placed: strings, holders, siding, adduce, doggy, figuratively, vertical, block,
# Nearest to frac: reactance, strokes, omega, cdot, bounced, constant, tarantula, right,
# Nearest to recorded: insulinotherapy, tour, album, posing, recall, stokely, tracks, band,
# Nearest to behind: voss, decomposition, chelsea, dkk, perceiving, sutherland, nrms, on,
# Nearest to san: francisco, california, expressive, vomit, mototsune, earthquakes, jose, edgy,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8151 0.6202 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8571 0.6368 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8253 0.6318 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8935 0.6364 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8667 0.6466 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8927 0.6339 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8820 0.4209 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8895 0.6317 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8348 0.6337 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8792 0.6409 sec/batch
# Nearest to these: are, many, other, weismann, despotism, miniature, midlands, have,
# Nearest to time: was, the, in, by, to, gmt, looting, of,
# Nearest to s: an, the, of, and, as, with, zero, a,
# Nearest to use: such, used, weapons, also, cutlery, chainmail, see, copland,
# Nearest to new: york, ny, becomes, leibniz, relentlessly, emergence, solidus, walla,
# Nearest to used: usage, pocock, abbreviation, use, refer, ser, borate, common,
# Nearest to are: have, other, many, usually, may, these, there, families,
# Nearest to b: jauron, biochemist, essayist, eleonore, athlete, quad, warlord, manush,
# Nearest to event: union, screwball, disaster, extinction, hg, loss, commemorate, events,
# Nearest to magazine: gregers, magazines, vets, gamespot, wmd, platoons, spivak, publication,
# Nearest to except: twice, tunisia, viciously, gir, occupies, safeguarding, fragmenting, sahrawi,
# Nearest to placed: strings, vertical, figuratively, adduce, doggy, holders, block, siding,
# Nearest to frac: reactance, omega, strokes, cdot, bounced, tarantula, right, constant,
# Nearest to recorded: insulinotherapy, tour, album, recall, posing, stokely, band, tracks,
# Nearest to behind: voss, decomposition, dkk, chelsea, sutherland, constituency, ex, perceiving,
# Nearest to san: francisco, vomit, california, expressive, mototsune, earthquakes, jose, sandpaper,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8238 0.6259 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8375 0.6351 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8179 0.6348 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8485 0.6185 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8567 0.6464 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8613 0.6259 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.9036 0.6472 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7721 0.6392 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8518 0.6340 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7947 0.6310 sec/batch
# Nearest to these: are, other, many, than, have, and, distinct, that,
# Nearest to time: the, in, by, was, gmt, to, looting, immunodeficiency,
# Nearest to s: an, the, of, zero, and, as, with, a,
# Nearest to use: such, used, also, for, weapons, other, see, as,
# Nearest to new: york, ny, emergence, becomes, leibniz, relentlessly, dss, lobbied,
# Nearest to used: usage, pocock, use, abbreviation, for, commonly, common, refer,
# Nearest to are: other, many, have, of, these, usually, may, and,
# Nearest to b: acrylamide, jauron, quad, octets, nsted, differentials, casteljau, eyeless,
# Nearest to event: union, screwball, disaster, extinction, hg, commemorate, events, dac,
# Nearest to magazine: gregers, vets, magazines, gamespot, spine, spivak, publication, platoons,
# Nearest to except: tunisia, twice, but, as, part, it, the, occupies,
# Nearest to placed: block, doggy, adduce, strings, figuratively, escapes, vertical, siding,
# Nearest to frac: omega, strokes, reactance, right, cdot, bounced, tarantula, constant,
# Nearest to recorded: insulinotherapy, tour, posing, recall, stokely, album, november, tracks,
# Nearest to behind: voss, decomposition, dkk, chelsea, sutherland, constituency, ex, on,
# Nearest to san: francisco, california, vomit, jose, expressive, mototsune, diego, fresno,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.8062 0.6362 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8175 0.6318 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.9027 0.6422 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8332 0.6375 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8553 0.6333 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9169 0.6318 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8408 0.6286 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8311 0.6587 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8429 0.6482 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8626 0.6427 sec/batch
# Nearest to these: other, are, have, many, than, that, and, first,
# Nearest to time: the, in, to, was, by, gmt, which, immunodeficiency,
# Nearest to s: an, of, the, and, as, zero, a, from,
# Nearest to use: such, used, for, also, see, as, is, means,
# Nearest to new: york, emergence, ny, becomes, leibniz, lobbied, relentlessly, tulip,
# Nearest to used: usage, use, pocock, abbreviation, for, united, refer, imi,
# Nearest to are: have, other, may, many, usually, their, these, certain,
# Nearest to b: jauron, quad, acrylamide, casteljau, nsted, eyeless, biochemist, octets,
# Nearest to event: union, screwball, extinction, events, disaster, commemorate, hg, seismic,
# Nearest to magazine: gregers, magazines, vets, publication, spivak, gamespot, spine, wmd,
# Nearest to except: twice, tunisia, as, the, in, part, safeguarding, occupies,
# Nearest to placed: doggy, block, strings, adduce, figuratively, holders, bootstrap, vertical,
# Nearest to frac: omega, constant, reactance, cdot, strokes, right, tarantula, sinc,
# Nearest to recorded: insulinotherapy, tour, posing, album, stokely, recall, song, november,
# Nearest to behind: voss, decomposition, dkk, chelsea, sutherland, on, ex, impairments,
# Nearest to san: francisco, california, vomit, expressive, jose, mototsune, edgy, sandpaper,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8593 0.6478 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8992 0.6484 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8615 0.6520 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8381 0.6202 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.9029 0.6403 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8802 0.6443 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8680 0.6303 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8640 0.6431 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8064 0.6265 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8432 0.6394 sec/batch
# Nearest to these: other, are, many, have, that, than, both, and,
# Nearest to time: the, was, in, by, to, of, taking, gmt,
# Nearest to s: of, an, the, and, as, zero, two, a,
# Nearest to use: such, used, for, also, other, as, but, see,
# Nearest to new: york, emergence, ny, becomes, leibniz, lobbied, extended, federalists,
# Nearest to used: usage, use, pocock, for, abbreviation, most, refer, similar,
# Nearest to are: have, many, other, usually, and, of, may, these,
# Nearest to b: acrylamide, jauron, octets, casteljau, quad, nsted, dahlhaus, differentials,
# Nearest to event: union, screwball, events, extinction, disaster, hg, commemorate, dac,
# Nearest to magazine: gregers, magazines, vets, spine, spivak, gamespot, publication, wmd,
# Nearest to except: tunisia, as, twice, part, but, the, in, it,
# Nearest to placed: doggy, block, figuratively, adduce, siding, strings, holders, vertical,
# Nearest to frac: omega, reactance, tarantula, strokes, bounced, constant, cdot, sinc,
# Nearest to recorded: insulinotherapy, posing, tour, recall, album, november, stokely, tracks,
# Nearest to behind: voss, dkk, decomposition, chelsea, sutherland, according, noteworthy, impairments,
# Nearest to san: francisco, california, expressive, vomit, jose, mototsune, sandpaper, earthquakes,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8809 0.6494 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8600 0.6375 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9632 0.6483 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8869 0.6202 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8776 0.6397 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8429 0.6407 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.8034 0.6362 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8532 0.6335 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7727 0.6311 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8687 0.6445 sec/batch
# Nearest to these: are, other, have, than, many, possible, distinct, both,
# Nearest to time: the, was, in, looting, taking, by, which, to,
# Nearest to s: of, an, the, and, in, as, with, zero,
# Nearest to use: such, used, for, also, weapons, simple, cutlery, other,
# Nearest to new: york, becomes, ny, emergence, leibniz, lobbied, relentlessly, federalists,
# Nearest to used: usage, use, pocock, abbreviation, for, similar, commonly, refer,
# Nearest to are: have, many, usually, other, certain, these, there, of,
# Nearest to b: jauron, quad, manush, essayist, dahlhaus, eyeless, octets, pitcairn,
# Nearest to event: union, screwball, events, extinction, disaster, commemorate, hg, dac,
# Nearest to magazine: gregers, magazines, spine, gamespot, vets, publication, spivak, repeating,
# Nearest to except: tunisia, twice, part, it, as, but, suebi, preposition,
# Nearest to placed: block, doggy, strings, adduce, vertical, figuratively, siding, allophones,
# Nearest to frac: tarantula, bounced, omega, strokes, reactance, constant, right, cdot,
# Nearest to recorded: insulinotherapy, posing, tour, november, album, recall, stokely, song,
# Nearest to behind: voss, chelsea, dkk, sutherland, on, decomposition, impairments, noteworthy,
# Nearest to san: francisco, california, expressive, vomit, jose, mototsune, diego, fresno,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8599 0.6469 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8638 0.6384 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
